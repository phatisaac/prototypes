# %%
import streamlit as st
# Out:
# UsageError: Line magic function `%%writefile` not found.

# %%
import pandas as pd
import numpy as np
import pyreadstat

# %%
df, meta = pyreadstat.read_dta('pcs.dta')
df
# Out:
#      Sex  Maritalstatus  Educationlevel  Smoking  Alcohol  COPD  age_cat  \
# 0      0              4               2        0        1     0        3
# 1      0              1               3        0        0     0        1
# 2      0              3               3        0        0     0        1
# 3      0              2               3        1        1     0        4
# 4      1              2               2        1        1     1        4
# ..   ...            ...             ...      ...      ...   ...      ...
# 128    0              2               3        0        0     1        1
# 129    1              1               3        0        1     0        3
# 130    0              2               3        0        0     1        3
# 131    0              2               4        0        0     0        4
# 132    1              2               3        0        0     0        3
#
#      income        MCS        PCS
# 0         2  53.583332  59.375000
# 1         1  54.750000  48.750000
# 2         3  82.750000  81.875000
# 3         1  29.000000  35.000000
# 4         2  38.750000  26.250000
# ..      ...        ...        ...
# 128       1  36.750000  18.875000
# 129       1  54.500000  39.375000
# 130       1  44.375000  43.125000
# 131       3  66.625000  80.625000
# 132       3  83.750000  74.425003
#
# [133 rows x 10 columns]

# %%
st.title('Health and lifestyle Dashboard')
# Out:
# 2025-12-15 17:12:12.331 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 17:12:12.333 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
st.write('This is a simple interactive dashboard built from scratch')
# Out:
# 2025-12-15 17:12:30.453 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 17:12:30.455 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
st.subheader("dataset preview")
# Out:
# 2025-12-15 17:13:14.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 17:13:14.569 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
st.sidebar.head("user input")
option = st.sidebar.selectbox(

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd

# Load dataset
df = pd.read_csv('pcs.csv')  # adjust if your file is CSV or another format

# App title
st.title("Health & Lifestyle Dashboard")

# Dataset preview
st.subheader("Dataset Preview")
st.write(df.head())

# Sidebar filters
st.sidebar.header("User Input")

# Example: filter by smoking status
smoking_filter = st.sidebar.selectbox("Smoking Status", options=df["Smoking"].unique())
filtered_df = df[df["Smoking"] == smoking_filter]

# Show filtered data
st.subheader(f"Records with Smoking Status = {smoking_filter}")
st.write(filtered_df)

# Visualization: distribution of age categories
st.subheader("Age Category Distribution")
st.bar_chart(df["age_cat"].value_counts())

# Visualization: income vs PCS
st.subheader("Income vs PCS")
st.line_chart(df[["income", "PCS"]])

# %%
# !streamlit run app.py

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_stata("pcs.dta")

# App title
st.title("Health & Lifestyle Dashboard")

# Dataset preview
st.subheader("Dataset Preview")
st.write(df.head())

# Sidebar filters
st.sidebar.header("User Input")
smoking_filter = st.sidebar.selectbox("Smoking Status", options=df["Smoking"].unique())
filtered_df = df[df["Smoking"] == smoking_filter]

st.subheader(f"Records with Smoking Status = {smoking_filter}")
st.write(filtered_df)

# Age category distribution
st.subheader("Age Category Distribution")
st.bar_chart(df["age_cat"].value_counts())

# --- UPDATED ITEM ---
# Line plot: Income vs PCS
st.subheader("Line Plot: Income vs PCS")
fig_line, ax_line = plt.subplots()
sns.lineplot(x="income", y="PCS", data=df, marker="o", ax=ax_line)
ax_line.set_xlabel("Income")
ax_line.set_ylabel("PCS")
st.pyplot(fig_line)

# Boxplot: PCS vs Income
st.subheader("Boxplot: PCS vs Income")
fig1, ax1 = plt.subplots()
sns.boxplot(x="income", y="PCS", data=df, ax=ax1)
st.pyplot(fig1)

# Boxplot: MCS vs Educationlevel
st.subheader("Boxplot: MCS vs Education Level")
fig2, ax2 = plt.subplots()
sns.boxplot(x="Educationlevel", y="MCS", data=df, ax=ax2)
st.pyplot(fig2)

# Line plot: MCS vs Age
st.subheader("Line Plot: MCS vs Age")
fig3, ax3 = plt.subplots()
sns.lineplot(x="age_cat", y="MCS", data=df, marker="o", ax=ax3)
ax3.set_xlabel("Age Category")
ax3.set_ylabel("MCS")
st.pyplot(fig3)

# %%
# !streamlit run app.py
